# %% [markdown]
# # Pandas Plotting

# %%
# Pandas and numpy for data manipulation
import pandas as pd
import numpy as np

# Matplotlib and seaborn for plotting
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Series.plot()

# %%
random_series = np.random.randn(1000)
ts = pd.Series(random_series, index=pd.date_range('1/1/2018', periods=1000))
ts.plot()

# %%
ts.cumsum().plot()

# %% [markdown]
# ## DataFrame.plot()

# %%
random_serie_1 = np.random.randn(1000)
random_serie_2 = np.random.randn(1000)

df=pd.DataFrame({'serie_1':random_serie_1, 'serie_2':random_serie_2}, index=pd.date_range('1/1/2018', periods=1000))
df.cumsum().plot()

# %% [markdown]
# plot() function can be combined with matplotlib plotting functions

# %%
ts = pd.date_range('1/1/2005', periods=365)

df = pd.DataFrame(np.random.randn(365, 4), index=ts, columns=list('ABCD'))
df = df.cumsum()
df.plot(figsize=(5,5))
plt.title("Title");
df.head(5)
# Out:
#                    A         B         C         D
# 2005-01-01 -0.493657 -0.894073  0.360936 -1.248304
# 2005-01-02 -1.137556 -0.122733 -0.705601 -2.950390
# 2005-01-03 -0.104686  2.382409 -1.380665 -5.030258
# 2005-01-04  0.919540  2.796854 -2.627125 -5.500596
# 2005-01-05  0.471377  1.341472 -2.166959 -7.172858

# %%
df_milsa = pd.read_csv("../../resources/datasets/milsa.csv", index_col='Funcionario')
df_milsa.head(10)
# Out:
#             Est.civil     Inst  Filhos  Salario  Anos  Meses    Regiao
# Funcionario
# 1            solteiro  1o Grau     NaN     4.00    26      3  interior
# 2              casado  1o Grau     1.0     4.56    32     10   capital
# 3              casado  1o Grau     2.0     5.25    36      5   capital
# 4            solteiro  2o Grau     NaN     5.73    20     10     outro
# 5            solteiro  1o Grau     NaN     6.26    40      7     outro
# 6              casado  1o Grau     0.0     6.66    28      0  interior
# 7            solteiro  1o Grau     NaN     6.86    41      0  interior
# 8            solteiro  1o Grau     NaN     7.39    43      4   capital
# 9              casado  2o Grau     1.0     7.59    34     10   capital
# 10           solteiro  2o Grau     NaN     7.44    23      6     outro

# %%
df_milsa.sort_values(by=['Anos']).plot(x='Anos', y='Salario')

# %% [markdown]
# ## Plots - Part 1
#
# Plotting methods allow for a handful of plot styles other than the default line plot. These methods can be provided as the kind keyword argument to plot(), and include:
# * ‘bar’ or ‘barh’ for bar plots
# * ‘hist’ for histogram
# * ‘box’ for boxplot
# * ‘kde’ or ‘density’ for density plots
# * ‘area’ for area plots
# * ‘scatter’ for scatter plots
# * ‘hexbin’ for hexagonal bin plots
# * ‘pie’ for pie plots

# %% [markdown]
# ### Area Plot

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df.plot.area();

# %%
df.plot.area(stacked=False);

# %% [markdown]
# ### Scatter Plot

# %% [markdown]
# ### Pie Plot

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])
df.plot.scatter(x='a', y='b');

# %%
ax = df.plot.scatter(x='a', y='b', color='DarkBlue', label='Group 1');
df.plot.scatter(x='c', y='d', color='DarkGreen', label='Group 2', ax=ax); # multicolumn

# %%
df.plot.scatter(x='a', y='b', c='c', s=50);  # color

# %%
df.plot.scatter(x='a', y='b', s=df['c']*200);

# %%
df.plot.scatter(x='a', y='b', c='c', s=df['c']*200);

# %% [markdown]
# ### Bars and Horizontal Bars

# %%
df = pd.DataFrame(np.random.randn(365, 4), index=ts, columns=list('ABCD'))

df.iloc[5].plot(kind='bar')

plt.figure();df.iloc[6].plot.bar();

# %%
df.iloc[:5].plot(kind='bar');

# %%
plt.title("Data viz facens rocks!"); df.iloc[5].plot.bar(); plt.axhline(0, color='blue')

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df.plot.barh()
df.plot.bar()
df.plot.bar(stacked=True)
df.plot.barh(stacked=True)

# %% [markdown]
# ## Plots - Part 2

# %% [markdown]
# ### Histograms

# %%
df_milsa['Salario'].plot.hist(bins=5)

# %%
s = np.random.randn(1000)
plt.hist(s, color = 'blue', edgecolor = 'black',bins = 50)
# Out:
# (array([ 2.,  0.,  0.,  2.,  3.,  8.,  4.,  8.,  9.,  9., 13., 13., 14.,
#         23., 25., 33., 31., 32., 39., 36., 41., 42., 59., 44., 52., 55.,
#         51., 42., 40., 39., 30., 28., 25., 25., 27., 17., 21., 14., 11.,
#          8.,  5., 10.,  1.,  4.,  0.,  1.,  2.,  0.,  1.,  1.]),
#  array([-2.99316724, -2.86790813, -2.74264902, -2.61738991, -2.4921308 ,
#         -2.36687169, -2.24161258, -2.11635347, -1.99109436, -1.86583525,
#         -1.74057614, -1.61531703, -1.49005792, -1.36479881, -1.2395397 ,
#         -1.11428059, -0.98902148, -0.86376237, -0.73850326, -0.61324415,
#         -0.48798504, -0.36272593, -0.23746682, -0.11220771,  0.01305141,
#          0.13831052,  0.26356963,  0.38882874,  0.51408785,  0.63934696,
#          0.76460607,  0.88986518,  1.01512429,  1.1403834 ,  1.26564251,
#          1.39090162,  1.51616073,  1.64141984,  1.76667895,  1.89193806,
#          2.01719717,  2.14245628,  2.26771539,  2.3929745 ,  2.51823361,
#          2.64349272,  2.76875183,  2.89401094,  3.01927005,  3.14452916,
#          3.26978828]),
#  <a list of 50 Patch objects>)

# %%
df = pd.DataFrame(np.random.rand(1200), columns=['a'])
df.plot.hist()
df = pd.DataFrame(np.random.randn(1200), columns=['a'])
df.plot.hist(bins=100 )

# %%
df4 = pd.DataFrame({'a': np.random.randn(1000) + 1, 'b': np.random.randn(1000)}, columns=['a', 'b'])
df4.plot.hist(alpha=0.5)

# %%
df4['a'].plot.hist(orientation='horizontal')

# %%
df4['a'].hist()
df4['a'].diff().hist()

# %%
df4.hist(color='k', alpha=0.5, bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f35f7ee11d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35fc567f98>]],
#       dtype=object)

# %% [markdown]
# ### Density

# %%
ser = pd.Series(np.random.randn(1000))
ser.plot.hist()

# %%
ser.plot.kde()

# %%
ser = pd.Series(np.random.randn(1000))
ser.plot.hist(density=True);ser.plot.kde()

# %%
ser = pd.Series(np.random.randn(1000))
ser.plot.hist(density=True, bins=100);ser.plot.kde()

# %% [markdown]
# ### Box
#
# <img src="../../resources/images/simple.box.defs.gif" width="25%" />

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=['A', 'B', 'C', 'D', 'E'])
df.plot.box()

# %%
df_milsa = pd.read_csv("../../resources/datasets/milsa.csv", index_col="Funcionario")
df_milsa
# Out:
#             Est.civil      Inst  Filhos  Salario  Anos  Meses    Regiao
# Funcionario
# 1            solteiro   1o Grau     NaN     4.00    26      3  interior
# 2              casado   1o Grau     1.0     4.56    32     10   capital
# 3              casado   1o Grau     2.0     5.25    36      5   capital
# 4            solteiro   2o Grau     NaN     5.73    20     10     outro
# 5            solteiro   1o Grau     NaN     6.26    40      7     outro
# 6              casado   1o Grau     0.0     6.66    28      0  interior
# 7            solteiro   1o Grau     NaN     6.86    41      0  interior
# 8            solteiro   1o Grau     NaN     7.39    43      4   capital
# 9              casado   2o Grau     1.0     7.59    34     10   capital
# 10           solteiro   2o Grau     NaN     7.44    23      6     outro
# 11             casado   2o Grau     2.0     8.12    33      6  interior
# 12           solteiro   1o Grau     NaN     8.46    27     11   capital
# 13           solteiro   2o Grau     NaN     8.74    37      5     outro
# 14             casado   1o Grau     3.0     8.95    44      2     outro
# 15             casado   2o Grau     0.0     9.13    30      5  interior
# 16           solteiro   2o Grau     NaN     9.35    38      8     outro
# 17             casado   2o Grau     1.0     9.77    31      7   capital
# 18             casado   1o Grau     2.0     9.80    39      7     outro
# 19           solteiro  Superior     NaN    10.53    25      8  interior
# 20           solteiro   2o Grau     NaN    10.76    37      4  interior
# 21             casado   2o Grau     1.0    11.06    30      9     outro
# 22           solteiro   2o Grau     NaN    11.59    34      2   capital
# 23           solteiro   1o Grau     NaN    12.00    41      0     outro
# 24             casado  Superior     0.0    12.79    26      1     outro
# 25             casado   2o Grau     2.0    13.23    32      5  interior
# 26             casado   2o Grau     2.0    13.60    35      0     outro
# 27           solteiro   1o Grau     NaN    13.85    46      7     outro
# 28             casado   2o Grau     0.0    14.69    29      8  interior
# 29             casado   2o Grau     5.0    14.71    40      6  interior
# 30             casado   2o Grau     2.0    15.99    35     10   capital
# 31           solteiro  Superior     NaN    16.22    31      5     outro
# 32             casado   2o Grau     1.0    16.61    36      4  interior
# 33             casado  Superior     3.0    17.26    43      7   capital
# 34           solteiro  Superior     NaN    18.75    33      7   capital
# 35             casado   2o Grau     2.0    19.40    48     11   capital
# 36             casado  Superior     3.0    23.30    42      2  interior

# %%
df = pd.DataFrame(df_milsa[['Salario','Anos', 'Filhos']])
df.plot.box()

# %%
color = dict(boxes='DarkGreen', whiskers='DarkOrange',medians='DarkBlue', caps='Gray')
df.plot.box(color=color, sym='r*')

# %%
df.boxplot()

# %% [markdown]
# ### Violin Plots
#
# #### Comparison with Box Plot

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

# generate some random data
all_data = [np.random.randn(100) for std in range(0, 4)]


# plot box plot
axes[1].boxplot(all_data)
axes[1].set_title('box plot')

# plot violin plot
axes[0].violinplot(all_data,showmeans=False,showmedians=True)
axes[0].set_title('violin plot')


# adding horizontal grid lines
for ax in axes:
    ax.yaxis.grid(True)

plt.show()

# %%
df_milsa = pd.read_csv("../../resources/datasets/milsa.csv", index_col='Funcionario')
df_milsa.head(10)
# Out:
#             Est.civil     Inst  Filhos  Salario  Anos  Meses    Regiao
# Funcionario
# 1            solteiro  1o Grau     NaN     4.00    26      3  interior
# 2              casado  1o Grau     1.0     4.56    32     10   capital
# 3              casado  1o Grau     2.0     5.25    36      5   capital
# 4            solteiro  2o Grau     NaN     5.73    20     10     outro
# 5            solteiro  1o Grau     NaN     6.26    40      7     outro
# 6              casado  1o Grau     0.0     6.66    28      0  interior
# 7            solteiro  1o Grau     NaN     6.86    41      0  interior
# 8            solteiro  1o Grau     NaN     7.39    43      4   capital
# 9              casado  2o Grau     1.0     7.59    34     10   capital
# 10           solteiro  2o Grau     NaN     7.44    23      6     outro

# %%
plt.violinplot(df_milsa['Salario'],showmeans=False, showmedians=True) #default
plt.xticks([0,1,2], ('', 'Salario',''))
plt.show()
plt.violinplot(df_milsa['Salario'],showmeans=False, showmedians=True,widths = 0.5, bw_method=0.1) #default
plt.xticks([0,1,2], ('', 'Salario',''))
plt.show()

# %%
plt.violinplot(df_milsa['Salario'],showmeans=True, showmedians=True) 
plt.xticks([0,1,2], ('', 'Salario',''))
plt.show()
plt.violinplot(df_milsa['Salario'],showmeans=True, showmedians=True,bw_method=0.05)
plt.xticks([0,1,2], ('', 'Salario',''))
plt.show()

# %%
plt.violinplot([df_milsa['Salario'],df_milsa["Anos"]],showmeans=True, showmedians=True,widths = 0.1, bw_method=0.1) #default
plt.xticks([0,1,2], ('', 'Salario','Anos'))

plt.show()

# %%
plt.violinplot(all_data,showmeans=True, showmedians=False, widths = 0.5, bw_method=0.1) #default
plt.show()
plt.violinplot(all_data,showmeans=True, showmedians=False, widths = 1,   bw_method=0.1)
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(20, 3))

bw_method =[0.1 ,0.2,0.3 ,0.4,None] #last = default

# variating width and the estimator bandwidth of the KDE
for i in range(len(axes)):
    axes[i].violinplot(all_data,showmeans=True, showmedians=False, widths = 1, bw_method=bw_method[i])
    axes[i].set_title('estimator bandwidth = {0}'.format(bw_method[i]))

# adding horizontal grid lines
for ax in axes:
    ax.yaxis.grid(True)

plt.show()

# %% [markdown]
# ## Plotting Features / Strategies

# %% [markdown]
# ### Error Bars

# %%
df = pd.DataFrame(np.random.randn(365, 4), index=ts, columns=list('ABCD'))

df.iloc[5].plot(kind='bar')

plt.figure();df.iloc[6].plot.bar(yerr=0.3);

# %%
df = pd.DataFrame(np.random.rand(15, 4), columns=['a', 'b', 'c', 'd'])
df.plot.scatter(x='a', y='b', yerr=0.06);

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df.plot.scatter(x='a', y='b', yerr=0.06,xerr=0.02);

# %% [markdown]
# ### Subplots

# %%
df.plot(subplots=True, figsize=(6, 6));

# %%
df.plot(subplots=True, layout=(2, 2), figsize=(6, 6), sharex=False);

# %% [markdown]
# ## Plotting Tools for Exploratory Analysis

# %% [markdown]
# ### Scatter Matrix Plot

# %%
from pandas.plotting import scatter_matrix

# %%
df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='hist')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f35eeec1908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35eee543c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35eee00940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35eedb1ef0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f35eed6c588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35eed1da90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35eece0080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35eed10710>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f35eed10748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35eec7f1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35eec2f828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35eebe0da0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f35eeb9f320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35eebd08d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35eeb82ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f35eeb3f470>]],
#       dtype=object)

# %% [markdown]
# ### Bootstrap Plot
#
# Bootstrap plots are used to visually assess the uncertainty of a statistic, such as mean, median, midrange, etc. A random subset of a specified size is selected from a data set, the statistic in question is computed for this subset and the process is repeated a specified number of times. Resulting plots and histograms are what constitutes the bootstrap plot.

# %%
from pandas.plotting import bootstrap_plot

# %%
data = pd.Series(np.random.rand(1000))
bootstrap_plot(data, size=50, samples=500, color='blue')
